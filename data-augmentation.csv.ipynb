# %%
import pandas as pd

dataset_sentiment_oversampled = pd.read_csv("dataset_sentiment_oversampled.csv")
dataset_sentiment_oversampled
# Out:
#                             Show  Sentiment  \
# 0                The Pentaverate          0
# 1                    The Undoing          0
# 2                     Stay Close          0
# 3     The Haunting of Hill House          0
# 4                     The Nevers          0
# ...                          ...        ...
# 4995             Big Little Lies          0
# 4996                 Moon Knight          0
# 4997               Lisey's Story          0
# 4998       Marvel's The Punisher          0
# 4999             Big Little Lies          0
#
#                                                  Review
# 0     That the resulting show isn’t good doesn’t esp...
# 1     While beautiful to look at, the show struggles...
# 2     The trouble with Stay Close is that it's too f...
# 3     The virtuosity in the style is evident. That's...
# 4     This is really unpleasant, and that is all I h...
# ...                                                 ...
# ...

# %%
dataset_sentiment_0 = pd.read_csv("dataset_sentiment_0.csv")
dataset_sentiment_0
# Out:
#                     Show  Sentiment  \
# 0                Mad Men          0
# 1          Pieces of Her          0
# 2        Brave New World          0
# 3        Stranger Things          0
# 4                   Lost          0
# ...                  ...        ...
# 1832           MacGruber          0
# 1833  Marvel's Iron Fist          0
# 1834             Players          0
# 1835         The Endgame          0
# 1836    The Morning Show          0
#
#                                                  Review
# 0     With each new season, I try to remind myself t...
# 1     Well acted and highly suspenseful, the eight-p...
# 2     Huxley's novel was revolutionary when it was p...
# 3     What we're left with is a disjointed poorer sh...
# 4     The series squandered its final season in a mi...
# ...                                                 ...
# 1832  An unnecessary reminder that not everything th...
# 1833  Congratulations to Iron Fist, which just level...
# ...

# %%
difference_df = pd.concat(
    [dataset_sentiment_oversampled, dataset_sentiment_0]
).drop_duplicates(keep=False)

# Salvar o DataFrame resultante em um arquivo CSV
difference_df.to_csv("dataset_sentiment_0_generated.csv", index=False)

# Exibir o resultado
difference_df
# Out:
#                         Show  Sentiment  \
# 29               What If...?          0
# 43                      Halo          0
# 45            The First Lady          0
# 51                      Loki          0
# 69            Gentleman Jack          0
# ...                      ...        ...
# 1789  Nine Perfect Strangers          0
# 1807            Wolf Like Me          0
# 1813                   Ozark          0
# 1831                   Vigil          0
# 1832               MacGruber          0
#
#                                                  Review
# 29    "What If...?" is more of a "WTF?" Under all th...
# 43    The video game Halo excelled at letting player...
# 45    The writing is often clunky, obvious and fille...
# 51    Can't have a Multiverse of Madness without int...
# 69    The trouble with this period drama, based on t...
# ...                                                 ...
# 1789  Great monologues can exist in counterproductiv...
# ...
